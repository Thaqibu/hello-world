# %% [markdown]
# <a href="https://colab.research.google.com/github/Thaqibu/hello-world/blob/main/reading_from_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#testing to see if i can put the file into GITHUB
print("Im just testing rn")
# Out:
# Im just testing rn
